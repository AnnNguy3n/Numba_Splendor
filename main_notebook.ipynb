# %%
from main import n_games

# %%
from Agents.Agent_Random.agent import action as p1

# %%
print(n_games([p1,p1,p1,p1], num_game=10000, print_mode=False, per_file=[]))
# Out:
# 100 [25, 28, 23, 24, 0]
# 200 [50, 51, 56, 43, 0]
# 300 [72, 76, 81, 70, 1]
# 400 [100, 96, 108, 95, 1]
# 500 [129, 112, 136, 122, 1]
# 600 [150, 134, 163, 152, 1]
# 700 [175, 158, 187, 179, 1]
# 800 [204, 175, 204, 216, 1]
# 900 [230, 202, 226, 241, 1]
# 1000 [255, 225, 254, 265, 1]
# 1100 [287, 251, 274, 287, 1]
# 1200 [306, 281, 300, 312, 1]
# 1300 [325, 308, 326, 340, 1]
# 1400 [343, 337, 354, 365, 1]
# 1500 [368, 364, 367, 400, 1]
# 1600 [394, 389, 387, 429, 1]
# 1700 [416, 415, 412, 456, 1]
# 1800 [445, 448, 431, 475, 1]
# 1900 [474, 472, 454, 499, 1]
# 2000 [499, 495, 483, 522, 1]
# 2100 [518, 521, 507, 553, 1]
# 2200 [546, 545, 533, 575, 1]
# 2300 [570, 570, 558, 601, 1]
# 2400 [592, 599, 580, 628, 1]
# 2500 [622, 623, 595, 659, 1]
# 2600 [652, 647, 617, 683, 1]
# 2700 [678, 667, 644, 710, 1]
# 2800 [697, 698, 667, 737, 1]
# 2900 [728, 714, 696, 761, 1]
# 3000 [754, 736, 730, 779, 1]
# 3100 [774, 756, 767, 802, 1]
# 3200 [796, 780, 792, 831, 1]
# 3300 [827, 800, 823, 849, 1]
# ...
